# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('C:/Users/Dell/testset_edited.csv', parse_dates=['datetime_utc']) #Master is the cleaned dataset that Gautam gave
df.head()
# Out:
#   datetime_utc   time  _conds   _dewptm   _fog   _hail   _heatindexm   _hum  \
# 0   1996-11-01  11:00   Smoke       9.0      0       0           NaN   27.0
# 1   1996-11-01  14:00   Smoke      10.0      0       0           NaN   41.0
# 2   1996-11-01  16:00   Smoke      11.0      0       0           NaN   47.0
# 3   1996-11-01  17:00   Smoke      12.0      0       0           NaN   56.0
# 4   1996-11-01  18:00   Smoke      13.0      0       0           NaN   60.0
#
#     _precipm   _pressurem  ...   _snow   _tempm   _thunder   _tornado   _vism  \
# 0        NaN       1010.0  ...       0       30          0          0     5.0
# 1        NaN       1010.0  ...       0       24          0          0     2.0
# 2        NaN       1011.0  ...       0       23          0          0     1.2
# 3        NaN       1011.0  ...       0       21          0          0     NaN
# 4        NaN       1010.0  ...       0       21          0          0     0.8
#
# ...

# %%
df.columns = df.columns.to_series().apply(lambda x: x.strip()) # Stripping any extra spaces in the column names

# %%
df_actual1 =  df[['datetime_utc','_tempm']]
df_actual1.head(2)
# Out:
#   datetime_utc  _tempm
# 0   1996-11-01      30
# 1   1996-11-01      24

# %%
df_actual1.columns = ['Date','Temperature'] 
df_actual1.head()
# Out:
#         Date  Temperature
# 0 1996-11-01           30
# 1 1996-11-01           24
# 2 1996-11-01           23
# 3 1996-11-01           21
# 4 1996-11-01           21

# %%
df1=df_actual1.groupby("Date")["Temperature"].mean()

# %%
df1.to_csv(r'C:/Users/Dell/Actual.csv',header= False)

# %%
df_actual= pd.read_csv('C:/Users/Dell/Actual.csv')
df_actual.head(2)
# Out:
#    1996-11-01       22.0
# 0  1996-11-02  22.916667
# 1  1996-11-03  21.791667

# %%
df_actual.columns = ['Date','Temperature'] 
df_actual.head()
# Out:
#          Date  Temperature
# 0  1996-11-02    22.916667
# 1  1996-11-03    21.791667
# 2  1996-11-04    22.722222
# 3  1996-11-05    27.800000
# 4  1996-11-06    21.937500

# %%
df_predicted=pd.read_csv('Predicted.csv')#Data that sachin and meghana gave
df_predicted.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-0e925d53954e> in <module>
# ----> 1 df_predicted=pd.read_csv('Predicted.csv')#Data that sachin and meghana gave
#       2 df_predicted.head()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
# ...

# %%
df_predicted.columns = ['Date','Temperature'] 
df_predicted.head()
# Out:
#          Date  Temperature
# 0  2016-01-02    14.419211
# 1  2016-01-03    14.257527
# 2  2016-01-04    14.162619
# 3  2016-01-05    14.085521
# 4  2016-01-06    14.046775

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_predicted["Date"], y=df_predicted['Temperature'], name="Actual",
                         line_color='deepskyblue'))

fig.add_trace(go.Scatter(x=df_actual["Date"], y=df_actual['Temperature'], name="Predicted",
                         line_color='dimgray'))

fig.update_layout(title_text='Interactive Weather',
                  xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <div>
#
#
#             <div id="c39c1b9c-7af4-4ae7-8f62-a19f9d2e1aa3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c39c1b9c-7af4-4ae7-8f62-a19f9d2e1aa3")) {
#                     Plotly.newPlot(
#                         'c39c1b9c-7af4-4ae7-8f62-a19f9d2e1aa3',
# ...
